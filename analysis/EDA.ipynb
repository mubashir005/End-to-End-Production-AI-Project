# %%
import pandas as pd
import numpy as np

from analyze_src.basic_data_inspection import DataInspector,DataTypeInspectionStrategy,SummaryStatisticsInspectionStrategy
from analyze_src.missing_values_analysis import SimpleMissingValuesAnalysis
from analyze_src.univariate_analysis import NumericalUnivariateAnalysis,CategoricalUnivariateAnalysis,UnivariateAnalyzer
from analyze_src.bivariate_analysis import NumericalBiVariateAnalysis,BivariateAnalyzer,CategoticalBiVariateAnalysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
#load the data
data_path='../extracted_data/AmesHousing.csv'
df = pd.read_csv(data_path)

# %%
#step 1:basic data insepction
data_inspector = DataInspector(DataTypeInspectionStrategy())
data_inspector.execute_inspection(df)
# Out:
# Data Types and Non-null Counts
# <bound method DataFrame.info of       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# ...

# %%
# Switch strategy to Summary Statistics Inspection
data_inspector.set_strategy(SummaryStatisticsInspectionStrategy())
data_inspector.execute_inspection(df)
# Out:
# Summary Statetistics (Numerical Features:)
# <bound method NDFrame.describe of       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# ...

# %%
missing_values_analyzer = SimpleMissingValuesAnalysis()
missing_values_analyzer.analyze(df)
# Out:
# Missing Values Count by coloumns
# Lot Frontage       490
# Alley             2732
# Mas Vnr Type      1775
# Mas Vnr Area        23
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1422
# Garage Type        157
# Garage Yr Blt      159
# Garage Finish      159
# Garage Cars          1
# Garage Area          1
# Garage Qual        159
# Garage Cond        159
# Pool QC           2917
# Fence             2358
# Misc Feature      2824
# dtype: int64
#
# Missing Values visualization by coloumns

# %%
numerical_analysis = UnivariateAnalyzer(NumericalUnivariateAnalysis())
numerical_analysis.execute_analysis(df, 'SalePrice')

# %%
Categorical_Univariate_Analysis = UnivariateAnalyzer(CategoricalUnivariateAnalysis())
Categorical_Univariate_Analysis.execute_analysis(df, 'Neighborhood')
# Out:
# d:\Price_prediction\analysis\analyze_src\univariate_analysis.py:57: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette="muted")

# %%
Numerical_Bivariate_analyzer = BivariateAnalyzer(NumericalBiVariateAnalysis())
Numerical_Bivariate_analyzer.execute_analysis(df,'Gr Liv Area', 'SalePrice')

# %%
Categorical_Bivariate_Analysis = BivariateAnalyzer(CategoticalBiVariateAnalysis)
Categorical_Bivariate_Analysis.execute_analysis(df,'Overall Qual','SalePrice')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 Categorical_Bivariate_Analysis = BivariateAnalyzer(CategoticalBiVariateAnalysis)
# ----> 2 Categorical_Bivariate_Analysis.execute_analysis(df,'Overall Qual','SalePrice')
#
# File d:\Price_prediction\analysis\analyze_src\bivariate_analysis.py:77, in BivariateAnalyzer.execute_analysis(self, df, feature1, feature2)
#      76 def execute_analysis (self, df:pd.DataFrame,feature1:str,feature2:str):
# ---> 77     self._strategy.analyze(df,feature1,feature2)
#
# TypeError: CategoticalBiVariateAnalysis.analyze() missing 1 required positional argument: 'feature2'
