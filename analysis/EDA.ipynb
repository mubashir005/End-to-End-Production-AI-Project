# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in d:\price_prediction\.venv\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\price_prediction\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\price_prediction\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\price_prediction\.venv\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\price_prediction\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in d:\price_prediction\.venv\lib\site-packages (from matplotlib) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in d:\price_prediction\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in d:\price_prediction\.venv\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\price_prediction\.venv\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\price_prediction\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\price_prediction\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn

# %%
import pandas as pd
import numpy as np

from analyze_src.basic_data_inspection import DataInspector,DataTypeInspectionStrategy,SummaryStatisticsInspectionStrategy
from analyze_src.missing_values_analysis import SimpleMissingValuesAnalysis
from analyze_src.univariate_analysis import NumericalUnivariateAnalysis,CategoricalUnivariateAnalysis,UnivariateAnalyzer
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[37], line 6
#       4 from analyze_src.basic_data_inspection import DataInspector,DataTypeInspectionStrategy,SummaryStatisticsInspectionStrategy
#       5 from analyze_src.missing_values_analysis import SimpleMissingValuesAnalysis
# ----> 6 from analyze_src.univariate_analysis import NumericalUnivariateAnalysis,CategoricalUnivariateAnalysis,UnivariateAnalyzer
#       7 pd.set_option('display.max_columns', None)
#       8 pd.set_option('display.max_rows', 100)
#
# ImportError: cannot import name 'UnivariateAnalyzer' from 'analyze_src.univariate_analysis' (d:\Price_prediction\analysis\analyze_src\univariate_analysis.py)

# %%
#load the data
data_path='../extracted_data/AmesHousing.csv'
df = pd.read_csv(data_path)

# %%
#step 1:basic data insepction
data_inspector = DataInspector(DataTypeInspectionStrategy())
data_inspector.execute_inspection(df)
# Out:
# Data Types and Non-null Counts
# <bound method DataFrame.info of       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0      NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2      NaN       IR1          Lvl    AllPub     Corner        Gtl
# 3      NaN       Reg          Lvl    AllPub     Corner        Gtl
# 4      NaN       IR1          Lvl    AllPub     Inside        Gtl
# ...    ...       ...          ...       ...        ...        ...
# 2925   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 2926   NaN       IR1          Low    AllPub     Inside        Mod
# 2927   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2928   NaN       Reg          Lvl    AllPub     Inside        Mod
# 2929   NaN       Reg          Lvl    AllPub     Inside        Mod
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 0           NAmes        Norm        Norm      1Fam      1Story             6
# 1           NAmes       Feedr        Norm      1Fam      1Story             5
# 2           NAmes        Norm        Norm      1Fam      1Story             6
# 3           NAmes        Norm        Norm      1Fam      1Story             7
# 4         Gilbert        Norm        Norm      1Fam      2Story             5
# ...           ...         ...         ...       ...         ...           ...
# 2925      Mitchel        Norm        Norm      1Fam        SLvl             6
# 2926      Mitchel        Norm        Norm      1Fam      1Story             5
# 2927      Mitchel        Norm        Norm      1Fam      SFoyer             5
# 2928      Mitchel        Norm        Norm      1Fam      1Story             5
# 2929      Mitchel        Norm        Norm      1Fam      2Story             7
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 0                5        1960            1960        Hip   CompShg
# 1                6        1961            1961      Gable   CompShg
# 2                6        1958            1958        Hip   CompShg
# 3                5        1968            1968        Hip   CompShg
# 4                5        1997            1998      Gable   CompShg
# ...            ...         ...             ...        ...       ...
# 2925             6        1984            1984      Gable   CompShg
# 2926             5        1983            1983      Gable   CompShg
# 2927             5        1992            1992      Gable   CompShg
# 2928             5        1974            1975      Gable   CompShg
# 2929             5        1993            1994      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 0         BrkFace      Plywood        Stone         112.0         TA
# 1         VinylSd      VinylSd          NaN           0.0         TA
# 2         Wd Sdng      Wd Sdng      BrkFace         108.0         TA
# 3         BrkFace      BrkFace          NaN           0.0         Gd
# 4         VinylSd      VinylSd          NaN           0.0         TA
# ...           ...          ...          ...           ...        ...
# 2925      HdBoard      HdBoard          NaN           0.0         TA
# 2926      HdBoard      HdBoard          NaN           0.0         TA
# 2927      HdBoard      Wd Shng          NaN           0.0         TA
# 2928      HdBoard      HdBoard          NaN           0.0         TA
# 2929      HdBoard      HdBoard      BrkFace          94.0         TA
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 0            TA     CBlock        TA        Gd            Gd            BLQ
# 1            TA     CBlock        TA        TA            No            Rec
# 2            TA     CBlock        TA        TA            No            ALQ
# 3            TA     CBlock        TA        TA            No            ALQ
# 4            TA      PConc        Gd        TA            No            GLQ
# ...         ...        ...       ...       ...           ...            ...
# 2925         TA     CBlock        TA        TA            Av            GLQ
# 2926         TA     CBlock        Gd        TA            Av            BLQ
# 2927         TA      PConc        Gd        TA            Av            GLQ
# 2928         TA     CBlock        Gd        TA            Av            ALQ
# 2929         TA      PConc        Gd        TA            Av            LwQ
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 0            639.0            Unf           0.0        441.0         1080.0
# 1            468.0            LwQ         144.0        270.0          882.0
# 2            923.0            Unf           0.0        406.0         1329.0
# 3           1065.0            Unf           0.0       1045.0         2110.0
# 4            791.0            Unf           0.0        137.0          928.0
# ...            ...            ...           ...          ...            ...
# 2925         819.0            Unf           0.0        184.0         1003.0
# 2926         301.0            ALQ         324.0        239.0          864.0
# 2927         337.0            Unf           0.0        575.0          912.0
# 2928        1071.0            LwQ         123.0        195.0         1389.0
# 2929         758.0            Unf           0.0        238.0          996.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 0       GasA         Fa           Y      SBrkr        1656           0
# 1       GasA         TA           Y      SBrkr         896           0
# 2       GasA         TA           Y      SBrkr        1329           0
# 3       GasA         Ex           Y      SBrkr        2110           0
# 4       GasA         Gd           Y      SBrkr         928         701
# ...      ...        ...         ...        ...         ...         ...
# 2925    GasA         TA           Y      SBrkr        1003           0
# 2926    GasA         TA           Y      SBrkr         902           0
# 2927    GasA         TA           Y      SBrkr         970           0
# 2928    GasA         Gd           Y      SBrkr        1389           0
# 2929    GasA         Ex           Y      SBrkr         996        1004
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 0                   0         1656             1.0             0.0          1
# 1                   0          896             0.0             0.0          1
# 2                   0         1329             0.0             0.0          1
# 3                   0         2110             1.0             0.0          2
# 4                   0         1629             0.0             0.0          2
# ...               ...          ...             ...             ...        ...
# 2925                0         1003             1.0             0.0          1
# 2926                0          902             1.0             0.0          1
# 2927                0          970             0.0             1.0          1
# 2928                0         1389             1.0             0.0          1
# 2929                0         2000             0.0             0.0          2
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 0             0              3              1           TA              7
# 1             0              2              1           TA              5
# 2             1              3              1           Gd              6
# 3             1              3              1           Ex              8
# 4             1              3              1           TA              6
# ...         ...            ...            ...          ...            ...
# 2925          0              3              1           TA              6
# 2926          0              2              1           TA              5
# 2927          0              3              1           TA              6
# 2928          0              2              1           TA              6
# 2929          1              3              1           TA              9
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 0           Typ           2           Gd      Attchd         1960.0
# 1           Typ           0          NaN      Attchd         1961.0
# 2           Typ           0          NaN      Attchd         1958.0
# 3           Typ           2           TA      Attchd         1968.0
# 4           Typ           1           TA      Attchd         1997.0
# ...         ...         ...          ...         ...            ...
# 2925        Typ           0          NaN      Detchd         1984.0
# 2926        Typ           0          NaN      Attchd         1983.0
# 2927        Typ           0          NaN         NaN            NaN
# 2928        Typ           1           TA      Attchd         1975.0
# 2929        Typ           1           TA      Attchd         1993.0
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 0              Fin          2.0        528.0          TA          TA
# 1              Unf          1.0        730.0          TA          TA
# 2              Unf          1.0        312.0          TA          TA
# 3              Fin          2.0        522.0          TA          TA
# 4              Fin          2.0        482.0          TA          TA
# ...            ...          ...          ...         ...         ...
# 2925           Unf          2.0        588.0          TA          TA
# 2926           Unf          2.0        484.0          TA          TA
# 2927           NaN          0.0          0.0         NaN         NaN
# 2928           RFn          2.0        418.0          TA          TA
# 2929           Fin          3.0        650.0          TA          TA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 0              P           210             62               0           0
# 1              Y           140              0               0           0
# 2              Y           393             36               0           0
# 3              Y             0              0               0           0
# 4              Y           212             34               0           0
# ...          ...           ...            ...             ...         ...
# 2925           Y           120              0               0           0
# 2926           Y           164              0               0           0
# 2927           Y            80             32               0           0
# 2928           Y           240             38               0           0
# 2929           Y           190             48               0           0
#
#       Screen Porch  Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  \
# 0                0          0     NaN    NaN          NaN         0        5
# 1              120          0     NaN  MnPrv          NaN         0        6
# 2                0          0     NaN    NaN         Gar2     12500        6
# 3                0          0     NaN    NaN          NaN         0        4
# 4                0          0     NaN  MnPrv          NaN         0        3
# ...            ...        ...     ...    ...          ...       ...      ...
# 2925             0          0     NaN  GdPrv          NaN         0        3
# 2926             0          0     NaN  MnPrv          NaN         0        6
# 2927             0          0     NaN  MnPrv         Shed       700        7
# 2928             0          0     NaN    NaN          NaN         0        4
# 2929             0          0     NaN    NaN          NaN         0       11
#
#       Yr Sold Sale Type Sale Condition  SalePrice
# 0        2010       WD          Normal     215000
# 1        2010       WD          Normal     105000
# 2        2010       WD          Normal     172000
# 3        2010       WD          Normal     244000
# 4        2010       WD          Normal     189900
# ...       ...       ...            ...        ...
# 2925     2006       WD          Normal     142500
# 2926     2006       WD          Normal     131000
# 2927     2006       WD          Normal     132000
# 2928     2006       WD          Normal     170000
# 2929     2006       WD          Normal     188000
#
# [2930 rows x 82 columns]>

# %%
# Switch strategy to Summary Statistics Inspection
data_inspector.set_strategy(SummaryStatisticsInspectionStrategy())
data_inspector.execute_inspection(df)
# Out:
# Summary Statetistics (Numerical Features:)
# <bound method NDFrame.describe of       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0      NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2      NaN       IR1          Lvl    AllPub     Corner        Gtl
# 3      NaN       Reg          Lvl    AllPub     Corner        Gtl
# 4      NaN       IR1          Lvl    AllPub     Inside        Gtl
# ...    ...       ...          ...       ...        ...        ...
# 2925   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 2926   NaN       IR1          Low    AllPub     Inside        Mod
# 2927   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 2928   NaN       Reg          Lvl    AllPub     Inside        Mod
# 2929   NaN       Reg          Lvl    AllPub     Inside        Mod
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 0           NAmes        Norm        Norm      1Fam      1Story             6
# 1           NAmes       Feedr        Norm      1Fam      1Story             5
# 2           NAmes        Norm        Norm      1Fam      1Story             6
# 3           NAmes        Norm        Norm      1Fam      1Story             7
# 4         Gilbert        Norm        Norm      1Fam      2Story             5
# ...           ...         ...         ...       ...         ...           ...
# 2925      Mitchel        Norm        Norm      1Fam        SLvl             6
# 2926      Mitchel        Norm        Norm      1Fam      1Story             5
# 2927      Mitchel        Norm        Norm      1Fam      SFoyer             5
# 2928      Mitchel        Norm        Norm      1Fam      1Story             5
# 2929      Mitchel        Norm        Norm      1Fam      2Story             7
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 0                5        1960            1960        Hip   CompShg
# 1                6        1961            1961      Gable   CompShg
# 2                6        1958            1958        Hip   CompShg
# 3                5        1968            1968        Hip   CompShg
# 4                5        1997            1998      Gable   CompShg
# ...            ...         ...             ...        ...       ...
# 2925             6        1984            1984      Gable   CompShg
# 2926             5        1983            1983      Gable   CompShg
# 2927             5        1992            1992      Gable   CompShg
# 2928             5        1974            1975      Gable   CompShg
# 2929             5        1993            1994      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 0         BrkFace      Plywood        Stone         112.0         TA
# 1         VinylSd      VinylSd          NaN           0.0         TA
# 2         Wd Sdng      Wd Sdng      BrkFace         108.0         TA
# 3         BrkFace      BrkFace          NaN           0.0         Gd
# 4         VinylSd      VinylSd          NaN           0.0         TA
# ...           ...          ...          ...           ...        ...
# 2925      HdBoard      HdBoard          NaN           0.0         TA
# 2926      HdBoard      HdBoard          NaN           0.0         TA
# 2927      HdBoard      Wd Shng          NaN           0.0         TA
# 2928      HdBoard      HdBoard          NaN           0.0         TA
# 2929      HdBoard      HdBoard      BrkFace          94.0         TA
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 0            TA     CBlock        TA        Gd            Gd            BLQ
# 1            TA     CBlock        TA        TA            No            Rec
# 2            TA     CBlock        TA        TA            No            ALQ
# 3            TA     CBlock        TA        TA            No            ALQ
# 4            TA      PConc        Gd        TA            No            GLQ
# ...         ...        ...       ...       ...           ...            ...
# 2925         TA     CBlock        TA        TA            Av            GLQ
# 2926         TA     CBlock        Gd        TA            Av            BLQ
# 2927         TA      PConc        Gd        TA            Av            GLQ
# 2928         TA     CBlock        Gd        TA            Av            ALQ
# 2929         TA      PConc        Gd        TA            Av            LwQ
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 0            639.0            Unf           0.0        441.0         1080.0
# 1            468.0            LwQ         144.0        270.0          882.0
# 2            923.0            Unf           0.0        406.0         1329.0
# 3           1065.0            Unf           0.0       1045.0         2110.0
# 4            791.0            Unf           0.0        137.0          928.0
# ...            ...            ...           ...          ...            ...
# 2925         819.0            Unf           0.0        184.0         1003.0
# 2926         301.0            ALQ         324.0        239.0          864.0
# 2927         337.0            Unf           0.0        575.0          912.0
# 2928        1071.0            LwQ         123.0        195.0         1389.0
# 2929         758.0            Unf           0.0        238.0          996.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 0       GasA         Fa           Y      SBrkr        1656           0
# 1       GasA         TA           Y      SBrkr         896           0
# 2       GasA         TA           Y      SBrkr        1329           0
# 3       GasA         Ex           Y      SBrkr        2110           0
# 4       GasA         Gd           Y      SBrkr         928         701
# ...      ...        ...         ...        ...         ...         ...
# 2925    GasA         TA           Y      SBrkr        1003           0
# 2926    GasA         TA           Y      SBrkr         902           0
# 2927    GasA         TA           Y      SBrkr         970           0
# 2928    GasA         Gd           Y      SBrkr        1389           0
# 2929    GasA         Ex           Y      SBrkr         996        1004
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 0                   0         1656             1.0             0.0          1
# 1                   0          896             0.0             0.0          1
# 2                   0         1329             0.0             0.0          1
# 3                   0         2110             1.0             0.0          2
# 4                   0         1629             0.0             0.0          2
# ...               ...          ...             ...             ...        ...
# 2925                0         1003             1.0             0.0          1
# 2926                0          902             1.0             0.0          1
# 2927                0          970             0.0             1.0          1
# 2928                0         1389             1.0             0.0          1
# 2929                0         2000             0.0             0.0          2
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 0             0              3              1           TA              7
# 1             0              2              1           TA              5
# 2             1              3              1           Gd              6
# 3             1              3              1           Ex              8
# 4             1              3              1           TA              6
# ...         ...            ...            ...          ...            ...
# 2925          0              3              1           TA              6
# 2926          0              2              1           TA              5
# 2927          0              3              1           TA              6
# 2928          0              2              1           TA              6
# 2929          1              3              1           TA              9
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 0           Typ           2           Gd      Attchd         1960.0
# 1           Typ           0          NaN      Attchd         1961.0
# 2           Typ           0          NaN      Attchd         1958.0
# 3           Typ           2           TA      Attchd         1968.0
# 4           Typ           1           TA      Attchd         1997.0
# ...         ...         ...          ...         ...            ...
# 2925        Typ           0          NaN      Detchd         1984.0
# 2926        Typ           0          NaN      Attchd         1983.0
# 2927        Typ           0          NaN         NaN            NaN
# 2928        Typ           1           TA      Attchd         1975.0
# 2929        Typ           1           TA      Attchd         1993.0
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 0              Fin          2.0        528.0          TA          TA
# 1              Unf          1.0        730.0          TA          TA
# 2              Unf          1.0        312.0          TA          TA
# 3              Fin          2.0        522.0          TA          TA
# 4              Fin          2.0        482.0          TA          TA
# ...            ...          ...          ...         ...         ...
# 2925           Unf          2.0        588.0          TA          TA
# 2926           Unf          2.0        484.0          TA          TA
# 2927           NaN          0.0          0.0         NaN         NaN
# 2928           RFn          2.0        418.0          TA          TA
# 2929           Fin          3.0        650.0          TA          TA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 0              P           210             62               0           0
# 1              Y           140              0               0           0
# 2              Y           393             36               0           0
# 3              Y             0              0               0           0
# 4              Y           212             34               0           0
# ...          ...           ...            ...             ...         ...
# 2925           Y           120              0               0           0
# 2926           Y           164              0               0           0
# 2927           Y            80             32               0           0
# 2928           Y           240             38               0           0
# 2929           Y           190             48               0           0
#
#       Screen Porch  Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  \
# 0                0          0     NaN    NaN          NaN         0        5
# 1              120          0     NaN  MnPrv          NaN         0        6
# 2                0          0     NaN    NaN         Gar2     12500        6
# 3                0          0     NaN    NaN          NaN         0        4
# 4                0          0     NaN  MnPrv          NaN         0        3
# ...            ...        ...     ...    ...          ...       ...      ...
# 2925             0          0     NaN  GdPrv          NaN         0        3
# 2926             0          0     NaN  MnPrv          NaN         0        6
# 2927             0          0     NaN  MnPrv         Shed       700        7
# 2928             0          0     NaN    NaN          NaN         0        4
# 2929             0          0     NaN    NaN          NaN         0       11
#
#       Yr Sold Sale Type Sale Condition  SalePrice
# 0        2010       WD          Normal     215000
# 1        2010       WD          Normal     105000
# 2        2010       WD          Normal     172000
# 3        2010       WD          Normal     244000
# 4        2010       WD          Normal     189900
# ...       ...       ...            ...        ...
# 2925     2006       WD          Normal     142500
# 2926     2006       WD          Normal     131000
# 2927     2006       WD          Normal     132000
# 2928     2006       WD          Normal     170000
# 2929     2006       WD          Normal     188000
#
# [2930 rows x 82 columns]>
#
# Summary Statetistics (Categorical Features:)
#        MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# count       2930   2930   198      2930         2930      2930       2930
# unique         7      2     2         4            4         3          5
# top           RL   Pave  Grvl       Reg          Lvl    AllPub     Inside
# freq        2273   2918   120      1859         2633      2927       2140
#
#        Land Slope Neighborhood Condition 1 Condition 2 Bldg Type House Style  \
# count        2930         2930        2930        2930      2930        2930
# unique          3           28           9           8         5           8
# top           Gtl        NAmes        Norm        Norm      1Fam      1Story
# freq         2789          443        2522        2900      2425        1481
#
#        Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type Exter Qual  \
# count        2930      2930         2930         2930         1155       2930
# unique          6         8           16           17            4          4
# top         Gable   CompShg      VinylSd      VinylSd      BrkFace         TA
# freq         2321      2887         1026         1015          880       1799
#
#        Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# count        2930       2930      2850      2850          2847           2850
# unique          5          6         5         5             4              6
# top            TA      PConc        TA        TA            No            GLQ
# freq         2549       1310      1283      2616          1906            859
#
#        BsmtFin Type 2 Heating Heating QC Central Air Electrical Kitchen Qual  \
# count            2849    2930       2930        2930       2929         2930
# unique              6       6          5           2          5            5
# top               Unf    GasA         Ex           Y      SBrkr           TA
# freq             2499    2885       1495        2734       2682         1494
#
#        Functional Fireplace Qu Garage Type Garage Finish Garage Qual  \
# count        2930         1508        2773          2771        2771
# unique          8            5           6             3           5
# top           Typ           Gd      Attchd           Unf          TA
# freq         2728          744        1731          1231        2615
#
#        Garage Cond Paved Drive Pool QC  Fence Misc Feature Sale Type  \
# count         2771        2930      13    572          106      2930
# unique           5           3       4      4            5        10
# top             TA           Y      Ex  MnPrv         Shed       WD
# freq          2665        2652       4    330           95      2536
#
#        Sale Condition
# count            2930
# unique              6
# top            Normal
# freq             2413

# %%
missing_values_analyzer = SimpleMissingValuesAnalysis()
missing_values_analyzer.analyze(df)
# Out:
# Missing Values Count by coloumns
# Lot Frontage       490
# Alley             2732
# Mas Vnr Type      1775
# Mas Vnr Area        23
# Bsmt Qual           80
# Bsmt Cond           80
# Bsmt Exposure       83
# BsmtFin Type 1      80
# BsmtFin SF 1         1
# BsmtFin Type 2      81
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Electrical           1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1422
# Garage Type        157
# Garage Yr Blt      159
# Garage Finish      159
# Garage Cars          1
# Garage Area          1
# Garage Qual        159
# Garage Cond        159
# Pool QC           2917
# Fence             2358
# Misc Feature      2824
# dtype: int64
#
# Missing Values visualization by coloumns

# %%
numerical_analysis = UnivariateAnalyzer(NumericalUnivariateAnalysis())
numerical_analysis.execute_analysis(df, 'SalePrice')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 numerical_analysis = UnivariateAnalysisStrategy(NumericalUnivariateAnalysis())
# ----> 2 numerical_analysis.execute_analysis(df, 'SalePrice')
#
# File d:\Price_prediction\analysis\analyze_src\univariate_analysis.py:74, in UnivariateAnalysisStrategy.execute_analysis(self, df, feature)
#      73 def execute_analysis(self,df:pd.DataFrame,feature:str):
# ---> 74     self._strategy.analyze(df)
#
# TypeError: NumericalUnivariateAnalysis.analyze() missing 1 required positional argument: 'feature'

# %%
Categorical_Univariate_Analysis = UnivariateAnalyzer(CategoricalUnivariateAnalysis())
Categorical_Univariate_Analysis.execute_analysis(df, 'SalePrice')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 Categorical_Univariate_Analysis = UnivariateAnalyzer(CategoricalUnivariateAnalysis())
#       2 Categorical_Univariate_Analysis.execute_analysis(df, 'SalePrice')
#
# NameError: name 'UnivariateAnalyzer' is not defined
